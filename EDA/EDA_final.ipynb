# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
por = pd.read_csv("C:/Users/DCU/Desktop/Data/student-por.csv",delimiter=';')
mat = pd.read_csv("C:/Users/DCU/Desktop/Data/student-mat.csv", delimiter=';')

# %%
if por.isnull().values.any():
    print("Student-por has missing values")
else:
    print("Student-por is missing value free")        
    
if mat.isnull().values.any():
    print("Student-mat has missing values")
else:
    print("Student-mat is missing value free")
# Out:
# Student-por is missing value free
# Student-mat is missing value free

# %%
por.duplicated().value_counts()
# Out:
# False    649
# dtype: int64

# %%
mat.duplicated().value_counts()
# Out:
# False    395
# dtype: int64

# %%
por.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
mat.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
describe_both = 'Pro: '+por.describe().astype(str) +'- Mat: '+ mat.describe().astype(str)

# %%
describe_both
# Out:
#                                                     age  \
# count                            Pro: 649.0- Mat: 395.0
# mean     Pro: 16.7442218798151- Mat: 16.696202531645568
# std    Pro: 1.2181376394800618- Mat: 1.2760427246056245
# min                                Pro: 15.0- Mat: 15.0
# 25%                                Pro: 16.0- Mat: 16.0
# 50%                                Pro: 17.0- Mat: 17.0
# 75%                                Pro: 18.0- Mat: 18.0
# max                                Pro: 22.0- Mat: 22.0
#
#                                                    Medu  \
# count                            Pro: 649.0- Mat: 395.0
# mean     Pro: 2.514637904468413- Mat: 2.749367088607595
# std    Pro: 1.1345519999533142- Mat: 1.0947351414285373
# min                                  Pro: 0.0- Mat: 0.0
# 25%                                  Pro: 2.0- Mat: 2.0
# 50%                                  Pro: 2.0- Mat: 3.0
# 75%                                  Pro: 4.0- Mat: 4.0
# ...

# %%
por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
mat.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
por['course'] = 'por'
mat['course'] = 'mat'

# %%
combined_data = pd.concat([por, mat], ignore_index=True)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
# school        1044 non-null object
# sex           1044 non-null object
# age           1044 non-null int64
# address       1044 non-null object
# famsize       1044 non-null object
# Pstatus       1044 non-null object
# Medu          1044 non-null int64
# Fedu          1044 non-null int64
# Mjob          1044 non-null object
# Fjob          1044 non-null object
# reason        1044 non-null object
# guardian      1044 non-null object
# traveltime    1044 non-null int64
# studytime     1044 non-null int64
# failures      1044 non-null int64
# schoolsup     1044 non-null object
# famsup        1044 non-null object
# paid          1044 non-null object
# activities    1044 non-null object
# nursery       1044 non-null object
# higher        1044 non-null object
# internet      1044 non-null object
# romantic      1044 non-null object
# famrel        1044 non-null int64
# ...

# %%
combined_data.duplicated().value_counts()
# Out:
# False    1044
# dtype: int64

# %%
combined_data.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   M   20       U     LE3       A     2     2  services  services
# 1040     MS   M   17       U     LE3       T     3     1  services  services
# 1041     MS   M   21       R     GT3       T     1     1     other     other
# 1042     MS   M   18       R     LE3       T     3     2  services     other
# 1043     MS   M   19       U     LE3       T     1     1     other   at_home
#
#       ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 course
# 1039  ...        5     4     4     5       4       11   9   9   9    mat
# 1040  ...        4     5     3     4       2        3  14  16  16    mat
# 1041  ...        5     3     3     3       3        3  10   8   7    mat
# 1042  ...        4     1     3     4       5        0  11  12  10    mat
# 1043  ...        2     3     3     3       5        5   8   9   9    mat
#
# [5 rows x 34 columns]

# %%
#(KEEN, 2017)
f, ax = plt.subplots(figsize=(12, 10))
#sns.set(font_scale=1)
corr = combined_data.corr()
sns.heatmap(corr,vmin=0, vmax=1)

# %%
corr
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.130196 -0.138521    0.049216  -0.007870  0.282364
# Medu       -0.130196  1.000000  0.642063   -0.238181   0.090616 -0.187769
# Fedu       -0.138521  0.642063  1.000000   -0.196328   0.033458 -0.191390
# traveltime  0.049216 -0.238181 -0.196328    1.000000  -0.081328  0.087177
# studytime  -0.007870  0.090616  0.033458   -0.081328   1.000000 -0.152024
# failures    0.282364 -0.187769 -0.191390    0.087177  -0.152024  1.000000
# famrel      0.007162  0.015004  0.013066   -0.012578   0.012324 -0.053676
# freetime    0.002645  0.001054  0.002142   -0.007403  -0.094429  0.102679
# goout       0.118510  0.025614  0.030075    0.049740  -0.072941  0.074683
# Dalc        0.133453  0.001515 -0.000165    0.109423  -0.159665  0.116336
# Walc        0.098291 -0.029331  0.019524    0.084292  -0.229073  0.107432
# health     -0.029129 -0.013254  0.034288   -0.029002  -0.063044  0.048311
# ...

# %%
combined_data.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.130196 -0.138521    0.049216  -0.007870  0.282364
# Medu       -0.130196  1.000000  0.642063   -0.238181   0.090616 -0.187769
# Fedu       -0.138521  0.642063  1.000000   -0.196328   0.033458 -0.191390
# traveltime  0.049216 -0.238181 -0.196328    1.000000  -0.081328  0.087177
# studytime  -0.007870  0.090616  0.033458   -0.081328   1.000000 -0.152024
# failures    0.282364 -0.187769 -0.191390    0.087177  -0.152024  1.000000
# famrel      0.007162  0.015004  0.013066   -0.012578   0.012324 -0.053676
# freetime    0.002645  0.001054  0.002142   -0.007403  -0.094429  0.102679
# goout       0.118510  0.025614  0.030075    0.049740  -0.072941  0.074683
# Dalc        0.133453  0.001515 -0.000165    0.109423  -0.159665  0.116336
# Walc        0.098291 -0.029331  0.019524    0.084292  -0.229073  0.107432
# health     -0.029129 -0.013254  0.034288   -0.029002  -0.063044  0.048311
# ...

# %%
by_gender = combined_data.groupby('sex')
ages_mean_by_gender = by_gender['age'].mean()
print(ages_mean_by_gender)
# Out:
# sex
# F    16.768190
# M    16.671082
# Name: age, dtype: float64

# %%
by_school = combined_data.groupby('school')
ages_mean_by_school = by_school['age'].mean()
print(ages_mean_by_school)
# Out:
# school
# GP    16.601036
# MS    17.080882
# Name: age, dtype: float64

# %%
by_course = combined_data.groupby('course')
ages_mean_by_course = by_course['age'].mean()
print(ages_mean_by_course)
# Out:
# course
# mat    16.696203
# por    16.744222
# Name: age, dtype: float64

# %%
absences_mean_by_gender = by_gender['absences'].mean()
print(absences_mean_by_gender)
# Out:
# sex
# F    4.505922
# M    4.342163
# Name: absences, dtype: float64

# %%
absences_mean_by_school = by_school['absences'].mean()
print(absences_mean_by_school)
# Out:
# school
# GP    5.006477
# MS    2.812500
# Name: absences, dtype: float64

# %%
absences_mean_by_course = by_course['absences'].mean()
print(absences_mean_by_course)
# Out:
# course
# mat    5.708861
# por    3.659476
# Name: absences, dtype: float64

# %%
#(John Hunter, Darren Dale, Eric Firing, Michael Droettboom , 2019)
combined_data['sex'].value_counts().plot(kind='barh')

# %%
abs_students= combined_data[(combined_data.absences != 0)]
MS_abs_students = combined_data[(combined_data.absences != 0) & (combined_data.school =='MS')]
GP_abs_students = combined_data[(combined_data.absences != 0) & (combined_data.school =='GP')]
print("Total students who have absence days in MS school is: "+ str(len(MS_abs_students)))
print("Total students who have absence days in GP school is: "+ str(len(GP_abs_students)))
# Out:
# Total students who have absence days in MS school is: 158
# Total students who have absence days in GP school is: 527

# %%
abs_students.groupby('school').absences.count().plot(kind='barh')

# %%
combined_data.Medu.value_counts().plot(kind='barh')

# %%
combined_data.Fedu.value_counts().plot(x= "school",kind='barh')

# %%
#(Waskom, 2018)
sns.catplot(x="school", hue="course",col="sex", data=combined_data, kind="count",height=8, aspect=.9);

# %%
g = sns.catplot(x="sex", y="G1",hue="course", col="school",data=combined_data, kind="swarm",height=8, aspect=.9);

# %%
combined_data[(combined_data.school == 'GP') & (combined_data.course == 'por') & (combined_data.sex == 'F')
             & (combined_data.G1 == combined_data.G1.min())]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
#
#   freetime goout  Dalc  Walc  health absences G1  G2  G3 course
# 0        3     4     1     1       3        4  0  11  11    por
#
# [1 rows x 34 columns]

# %%
g2 = sns.catplot(x="sex", y="G2",hue="school", col="course",data=combined_data, kind="swarm",height=8, aspect=.9);

# %%
g3 = sns.catplot(x="sex", y="G3",hue="school", col="course",data=combined_data, kind="swarm",height=8, aspect=.9);

# %%
sns.scatterplot(x="G3", y="Medu", data=combined_data)

# %%
g3 = sns.catplot(x="famsize", y="G3",data=combined_data, kind="swarm",height=8, aspect=.9);

# %%
g3 = sns.catplot(x="famsize", y="G3",col='sex',data=combined_data, kind="swarm",height=8, aspect=.9);

# %%
sns.jointplot("G3", "absences", data=combined_data, kind="reg",
                  xlim=(0, 25), ylim=(0, 40), color="m", height=7)

# %%
sns.jointplot("G3", "studytime", data=combined_data, kind="reg",
                  xlim=(0, 25), ylim=(0, 8), color="m", height=7)
